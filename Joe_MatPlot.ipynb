# %% [markdown]
# <a href="https://colab.research.google.com/github/zwt4pb/ds2002/blob/main/Joe_MatPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df_movietitles = pd.read_csv('Top_Highest_Openings.csv')
df_movietitles = df_movies.sort_values(by='Total Gross', ascending=False)
df_movietitles.head()
# Out:
#                                         Release    Opening  Total Gross  \
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 0                             Avengers: Endgame  357115007    858373000
# 1                       Spider-Man: No Way Home  260138569    804793477
# 124                                      Avatar   77025481    749766139
# 44                            Top Gun: Maverick  126707459    718732821
#
#      % of Total  Theaters  Average        Date  \
# 3          26.5      4134    59982  18-12-2015
# 0          41.6      4662    76601  26-04-2019
# 1          32.3      4336    59995  17-12-2021
# 124        10.3      3452    22313  18-12-2009
# 44         17.6      4735    26759  27-05-2022
#
#                              Distributor
# 3    Walt Disney Studios Motion Pictures
# 0    Walt Disney Studios Motion Pictures
# 1                Sony Pictures Releasing
# 124                Twentieth Century Fox
# ...

# %%
top5movies = df_movies.head(5)
top5movies
# Out:
#                                         Release    Opening  Total Gross  \
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 0                             Avengers: Endgame  357115007    858373000
# 1                       Spider-Man: No Way Home  260138569    804793477
# 124                                      Avatar   77025481    749766139
# 44                            Top Gun: Maverick  126707459    718732821
#
#      % of Total  Theaters  Average        Date  \
# 3          26.5      4134    59982  18-12-2015
# 0          41.6      4662    76601  26-04-2019
# 1          32.3      4336    59995  17-12-2021
# 124        10.3      3452    22313  18-12-2009
# 44         17.6      4735    26759  27-05-2022
#
#                              Distributor
# 3    Walt Disney Studios Motion Pictures
# 0    Walt Disney Studios Motion Pictures
# 1                Sony Pictures Releasing
# 124                Twentieth Century Fox
# ...

# %%
top5movies = top5movies.replace({'Distributor': {'Walt Disney Studios Motion Pictures': 'Disney', 'Sony Pictures Releasing': 'Sony', 'Twentieth Century Fox': 'Fox'}})

# %%
bar_graph = plt.bar(top5movies['Distributor'], top5movies['Total Gross'])


plt.xlabel('Distributor')
plt.ylabel('Total Gross (Hundreds of Millions)')
plt.title('Top 5 Grossing Movies by Distributor')


plt.show()

# %%
pie_movies = plt.pie(top5movies['Total Gross'], labels=top5movies['Release'], autopct='%1.1f%%')


plt.title('Top 5 Grossing Movies')


plt.show()

# %%
scatterplot = plt.scatter(df_movietitles['Average'], df_movietitles['Total Gross'])

plt.xlabel('Average Earnings per Theater')
plt.ylabel('Total Earnings (Hundreds of Millions)')
plt.title('Average Earnings per Theater vs Total Earnings')

plt.show()
